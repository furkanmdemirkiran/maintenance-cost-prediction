# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error, r2_score
from sklearn.linear_model import LinearRegression

# %%
df = pd.read_excel("GrupC.xlsx")
df
# Out:
#     Bakim_ID Bakim_Onceligi     Vardiya Tesis_Bolgesi Makine_Saglik_Durumu  \
# 0    BKM1001          Dusuk        Gece         Guney             Kusursuz
# 1    BKM1002           Orta        Gece          Dogu             Kusursuz
# 2    BKM1003         Kritik        Gece          Batı            Yıpranmış
# 3    BKM1004         Kritik        Gece        Merkez                Zayıf
# 4    BKM1005           Orta  Hafta Sonu          Dogu               Kritik
# ..       ...            ...         ...           ...                  ...
# 495  BKM1496          Dusuk      Gunduz         Kuzey            Yıpranmış
# 496  BKM1497           Orta  Hafta Sonu         Kuzey            Yıpranmış
# 497  BKM1498         Yuksek  Hafta Sonu         Kuzey                Zayıf
# 498  BKM1499          Dusuk  Hafta Sonu          Dogu               Kritik
# 499  BKM1500         Kritik      Gunduz         Guney                  NaN
#
#      Makine_Yasi  Calisma_Saati  Titreşim_Seviyesi  Ariza_Sayisi  \
# 0            1.0         1960.0               1.16           3.0
# 1            7.0          924.0               1.40           1.0
# 2            5.0         2113.0               1.69           4.0
# 3           12.0         2898.0               2.20           0.0
# 4           10.0         1925.0               1.26           3.0
# ..           ...            ...                ...           ...
# 495          1.0         1354.0               2.34           5.0
# 496          6.0         1868.0               3.57           4.0
# 497         12.0         1797.0               1.55           3.0
# 498          4.0          875.0               0.88           2.0
# 499          8.0         1370.0               1.82           0.0
#
#      Duruş_Suresi_Saat  Ortam_Sicakligi  Toplam_Bakim_Maliyeti
# 0                 10.4             41.8               15767.85
# 1                  8.1             30.2               14756.24
# 2                  9.2             25.7               24976.29
# 3                  7.4             22.0               25770.41
# 4                  3.4             28.1               15910.66
# ..                 ...              ...                    ...
# 495               19.9             43.2               23918.19
# 496                3.6             33.1               24398.57
# 497                9.8             29.2               23983.28
# 498                8.5             38.7               18017.30
# 499                4.0             42.1               19508.40
#
# [500 rows x 12 columns]

# %%
df = df.drop("Bakim_ID", axis = 1)
df
# Out:
#     Bakim_Onceligi     Vardiya Tesis_Bolgesi Makine_Saglik_Durumu  \
# 0            Dusuk        Gece         Guney             Kusursuz
# 1             Orta        Gece          Dogu             Kusursuz
# 2           Kritik        Gece          Batı            Yıpranmış
# 3           Kritik        Gece        Merkez                Zayıf
# 4             Orta  Hafta Sonu          Dogu               Kritik
# ..             ...         ...           ...                  ...
# 495          Dusuk      Gunduz         Kuzey            Yıpranmış
# 496           Orta  Hafta Sonu         Kuzey            Yıpranmış
# 497         Yuksek  Hafta Sonu         Kuzey                Zayıf
# 498          Dusuk  Hafta Sonu          Dogu               Kritik
# 499         Kritik      Gunduz         Guney                  NaN
#
#      Makine_Yasi  Calisma_Saati  Titreşim_Seviyesi  Ariza_Sayisi  \
# 0            1.0         1960.0               1.16           3.0
# 1            7.0          924.0               1.40           1.0
# 2            5.0         2113.0               1.69           4.0
# 3           12.0         2898.0               2.20           0.0
# 4           10.0         1925.0               1.26           3.0
# ..           ...            ...                ...           ...
# 495          1.0         1354.0               2.34           5.0
# 496          6.0         1868.0               3.57           4.0
# 497         12.0         1797.0               1.55           3.0
# 498          4.0          875.0               0.88           2.0
# 499          8.0         1370.0               1.82           0.0
#
#      Duruş_Suresi_Saat  Ortam_Sicakligi  Toplam_Bakim_Maliyeti
# 0                 10.4             41.8               15767.85
# 1                  8.1             30.2               14756.24
# 2                  9.2             25.7               24976.29
# 3                  7.4             22.0               25770.41
# 4                  3.4             28.1               15910.66
# ..                 ...              ...                    ...
# 495               19.9             43.2               23918.19
# 496                3.6             33.1               24398.57
# 497                9.8             29.2               23983.28
# 498                8.5             38.7               18017.30
# 499                4.0             42.1               19508.40
#
# [500 rows x 11 columns]

# %%
df ["Bakim_Onceligi"].value_counts()
# Out:
# Orta      182
# Yuksek    127
# Dusuk     114
# Kritik     67
# ?          10
# Name: Bakim_Onceligi, dtype: int64

# %%
df[df["Bakim_Onceligi"] == "?"]
# Out:
#     Bakim_Onceligi     Vardiya Tesis_Bolgesi Makine_Saglik_Durumu  \
# 15               ?      Gunduz         Kuzey               Kritik
# 19               ?        Gece         Guney            Yıpranmış
# 61               ?        Gece         Kuzey                Zayıf
# 275              ?      Gunduz          Bati            Yıpranmış
# 318              ?        Gece         Guney             Kusursuz
# 406              ?  Hafta Sonu        Merkez               Kritik
# 454              ?        Gece         Guney               Kritik
# 478              ?         NaN        Merkez                Zayıf
# 481              ?      Gunduz        Merkez             Kusursuz
# 490              ?      Gunduz        Merkez                Zayıf
#
#      Makine_Yasi  Calisma_Saati  Titreşim_Seviyesi  Ariza_Sayisi  \
# 15           5.0         2033.0               1.18           1.0
# 19           9.0         2490.0               2.14           0.0
# 61           5.0         2157.0               1.82           1.0
# 275          1.0          743.0               1.06           1.0
# 318         10.0         1853.0               0.69           2.0
# 406          NaN          778.0               0.66           2.0
# 454          9.0          645.0               1.76           1.0
# 478         18.0        17497.0               0.54          11.0
# 481          5.0          792.0               0.87           3.0
# 490          3.0         2565.0               1.47          11.0
#
#      Duruş_Suresi_Saat  Ortam_Sicakligi  Toplam_Bakim_Maliyeti
# 15                 5.6             33.1               11750.69
# 19                 2.5             30.7               20129.60
# 61                12.5             39.1               18378.56
# 275                2.7             37.6               18656.34
# 318                6.2             28.8               21634.99
# 406               11.8             35.5               20482.86
# 454                7.4             24.4               19448.46
# 478                5.9             35.8               46775.88
# 481               10.2             42.8               13364.82
# 490                1.3             30.2               22286.23

# %%
df ["Bakim_Onceligi"] = df["Bakim_Onceligi"].replace("?", pd.NA)
df ["Bakim_Onceligi"].value_counts()
# Out:
# Orta      182
# Yuksek    127
# Dusuk     114
# Kritik     67
# Name: Bakim_Onceligi, dtype: int64

# %%
df["Vardiya"].value_counts()
# Out:
# Gunduz        274
# Gece          155
# Hafta Sonu     60
# Name: Vardiya, dtype: int64

# %%
df["Tesis_Bolgesi"].value_counts()
# Out:
# Merkez    133
# Kuzey     100
# Guney      97
# Dogu       80
# Bati       70
# Batı        7
# Name: Tesis_Bolgesi, dtype: int64

# %%
df ["Tesis_Bolgesi"] = df["Tesis_Bolgesi"].replace("Batı", "Bati")
df ["Tesis_Bolgesi"].value_counts()
# Out:
# Merkez    133
# Kuzey     100
# Guney      97
# Dogu       80
# Bati       77
# Name: Tesis_Bolgesi, dtype: int64

# %%
df["Makine_Saglik_Durumu"].value_counts()
# Out:
# Kritik       137
# Zayıf        134
# Yıpranmış     90
# Kusursuz      61
# İyi           42
# Name: Makine_Saglik_Durumu, dtype: int64

# %%
df.isnull().sum() #sutün kategorik ise mod | #sayısal değerler ise medyan ve mod
# Out:
# Bakim_Onceligi           10
# Vardiya                  11
# Tesis_Bolgesi            13
# Makine_Saglik_Durumu     36
# Makine_Yasi              14
# Calisma_Saati            18
# Titreşim_Seviyesi        16
# Ariza_Sayisi             15
# Duruş_Suresi_Saat        14
# Ortam_Sicakligi          14
# Toplam_Bakim_Maliyeti     0
# dtype: int64

# %%
x = df.groupby(["Tesis_Bolgesi", "Makine_Saglik_Durumu"])["Bakim_Onceligi"].transform(
    lambda x: x.mode()[0]

)
df["Bakim_Onceligi"] = df["Bakim_Onceligi"].fillna(x)
df["Bakim_Onceligi"].isnull().sum()
# Out:
# 0

# %%
x = df.groupby(["Tesis_Bolgesi", "Makine_Saglik_Durumu"])["Vardiya"].transform(
    lambda x: x.mode()[0]

)
df["Vardiya"] = df["Vardiya"].fillna(x)
df["Vardiya"].isnull().sum()
# Out:
# 1

# %%
x = df.groupby(["Vardiya", "Makine_Saglik_Durumu"])["Tesis_Bolgesi"].transform(
    lambda x: x.mode()[0]

)
df["Tesis_Bolgesi"] = df["Tesis_Bolgesi"].fillna(x)
df["Tesis_Bolgesi"].isnull().sum()
# Out:
# 1

# %%
x = df.groupby(["Vardiya"])["Tesis_Bolgesi"].transform(
    lambda x: x.mode()[0]

)
df["Tesis_Bolgesi"] = df["Tesis_Bolgesi"].fillna(x)
df["Tesis_Bolgesi"].isnull().sum()
# Out:
# 0

# %%
x = df.groupby(["Vardiya", "Tesis_Bolgesi"])["Makine_Saglik_Durumu"].transform(
    lambda x: x.mode()[0]

)
df["Makine_Saglik_Durumu"] = df["Makine_Saglik_Durumu"].fillna(x)
df["Makine_Saglik_Durumu"].isnull().sum()
# Out:
# 1

# %%
x = df.groupby(["Vardiya", "Tesis_Bolgesi"])["Makine_Yasi"].transform("median")
df["Makine_Yasi"] = df["Makine_Yasi"].fillna(x)
df["Makine_Yasi"].isnull().sum()
# Out:
# 0

# %%
x = df.groupby(["Vardiya", "Tesis_Bolgesi"])["Calisma_Saati"].transform("median")
df["Calisma_Saati"] = df["Calisma_Saati"].fillna(x)
df["Calisma_Saati"].isnull().sum()
# Out:
# 0

# %%
x = df.groupby(["Vardiya", "Tesis_Bolgesi"])["Titreşim_Seviyesi"].transform("mean")
df["Titreşim_Seviyesi"] = df["Titreşim_Seviyesi"].fillna(x)
df["Titreşim_Seviyesi"].isnull().sum()
# Out:
# 0

# %%
x = df.groupby(["Vardiya", "Tesis_Bolgesi"])["Ariza_Sayisi"].transform("median")
df["Ariza_Sayisi"] = df["Ariza_Sayisi"].fillna(x)
df["Ariza_Sayisi"].isnull().sum()
# Out:
# 0

# %%
x = df.groupby(["Vardiya", "Tesis_Bolgesi"])["Duruş_Suresi_Saat"].transform("median")
df["Duruş_Suresi_Saat"] = df["Ariza_Sayisi"].fillna(x)
df["Duruş_Suresi_Saat"].isnull().sum()
# Out:
# 0

# %%
x = df.groupby(["Vardiya", "Tesis_Bolgesi"])["Ortam_Sicakligi"].transform("median")
df["Ortam_Sicakligi"] = df["Ortam_Sicakligi"].fillna(x)
df["Ortam_Sicakligi"].isnull().sum()
# Out:
# 0

# %%
df.isnull().sum()
# Out:
# Bakim_Onceligi           0
# Vardiya                  1
# Tesis_Bolgesi            0
# Makine_Saglik_Durumu     1
# Makine_Yasi              0
# Calisma_Saati            0
# Titreşim_Seviyesi        0
# Ariza_Sayisi             0
# Duruş_Suresi_Saat        0
# Ortam_Sicakligi          0
# Toplam_Bakim_Maliyeti    0
# dtype: int64

# %%
df
# Out:
#     Bakim_Onceligi     Vardiya Tesis_Bolgesi Makine_Saglik_Durumu  \
# 0            Dusuk        Gece         Guney             Kusursuz
# 1             Orta        Gece          Dogu             Kusursuz
# 2           Kritik        Gece          Bati            Yıpranmış
# 3           Kritik        Gece        Merkez                Zayıf
# 4             Orta  Hafta Sonu          Dogu               Kritik
# ..             ...         ...           ...                  ...
# 495          Dusuk      Gunduz         Kuzey            Yıpranmış
# 496           Orta  Hafta Sonu         Kuzey            Yıpranmış
# 497         Yuksek  Hafta Sonu         Kuzey                Zayıf
# 498          Dusuk  Hafta Sonu          Dogu               Kritik
# 499         Kritik      Gunduz         Guney                Zayıf
#
#      Makine_Yasi  Calisma_Saati  Titreşim_Seviyesi  Ariza_Sayisi  \
# 0            1.0         1960.0               1.16           3.0
# 1            7.0          924.0               1.40           1.0
# 2            5.0         2113.0               1.69           4.0
# 3           12.0         2898.0               2.20           0.0
# 4           10.0         1925.0               1.26           3.0
# ..           ...            ...                ...           ...
# 495          1.0         1354.0               2.34           5.0
# 496          6.0         1868.0               3.57           4.0
# 497         12.0         1797.0               1.55           3.0
# 498          4.0          875.0               0.88           2.0
# 499          8.0         1370.0               1.82           0.0
#
#      Duruş_Suresi_Saat  Ortam_Sicakligi  Toplam_Bakim_Maliyeti
# 0                  3.0             41.8               15767.85
# 1                  1.0             30.2               14756.24
# 2                  4.0             25.7               24976.29
# 3                  0.0             22.0               25770.41
# 4                  3.0             28.1               15910.66
# ..                 ...              ...                    ...
# 495                5.0             43.2               23918.19
# 496                4.0             33.1               24398.57
# 497                3.0             29.2               23983.28
# 498                2.0             38.7               18017.30
# 499                0.0             42.1               19508.40
#
# [500 rows x 11 columns]

# %%
df= pd.get_dummies(df, columns=["Vardiya","Tesis_Bolgesi"], drop_first=True, dtype=int)
df
# Out:
#     Bakim_Onceligi Makine_Saglik_Durumu  Makine_Yasi  Calisma_Saati  \
# 0            Dusuk             Kusursuz          1.0         1960.0
# 1             Orta             Kusursuz          7.0          924.0
# 2           Kritik            Yıpranmış          5.0         2113.0
# 3           Kritik                Zayıf         12.0         2898.0
# 4             Orta               Kritik         10.0         1925.0
# ..             ...                  ...          ...            ...
# 495          Dusuk            Yıpranmış          1.0         1354.0
# 496           Orta            Yıpranmış          6.0         1868.0
# 497         Yuksek                Zayıf         12.0         1797.0
# 498          Dusuk               Kritik          4.0          875.0
# 499         Kritik                Zayıf          8.0         1370.0
#
#      Titreşim_Seviyesi  Ariza_Sayisi  Duruş_Suresi_Saat  Ortam_Sicakligi  \
# 0                 1.16           3.0                3.0             41.8
# 1                 1.40           1.0                1.0             30.2
# 2                 1.69           4.0                4.0             25.7
# 3                 2.20           0.0                0.0             22.0
# 4                 1.26           3.0                3.0             28.1
# ..                 ...           ...                ...              ...
# 495               2.34           5.0                5.0             43.2
# 496               3.57           4.0                4.0             33.1
# 497               1.55           3.0                3.0             29.2
# 498               0.88           2.0                2.0             38.7
# 499               1.82           0.0                0.0             42.1
#
#      Toplam_Bakim_Maliyeti  Vardiya_Gunduz  Vardiya_Hafta Sonu  \
# 0                 15767.85               0                   0
# 1                 14756.24               0                   0
# 2                 24976.29               0                   0
# 3                 25770.41               0                   0
# 4                 15910.66               0                   1
# ..                     ...             ...                 ...
# 495               23918.19               1                   0
# 496               24398.57               0                   1
# 497               23983.28               0                   1
# 498               18017.30               0                   1
# 499               19508.40               1                   0
#
#      Tesis_Bolgesi_Dogu  Tesis_Bolgesi_Guney  Tesis_Bolgesi_Kuzey  \
# 0                     0                    1                    0
# 1                     1                    0                    0
# 2                     0                    0                    0
# 3                     0                    0                    0
# 4                     1                    0                    0
# ..                  ...                  ...                  ...
# 495                   0                    0                    1
# 496                   0                    0                    1
# 497                   0                    0                    1
# 498                   1                    0                    0
# 499                   0                    1                    0
#
#      Tesis_Bolgesi_Merkez
# 0                       0
# 1                       0
# 2                       0
# 3                       1
# 4                       0
# ..                    ...
# 495                     0
# 496                     0
# 497                     0
# 498                     0
# 499                     0
#
# [500 rows x 15 columns]

# %%
df ["Bakim_Onceligi"].value_counts()
# Out:
# Orta      189
# Yuksek    128
# Dusuk     116
# Kritik     67
# Name: Bakim_Onceligi, dtype: int64

# %%
df["Bakim_Onceligi"] = df ["Bakim_Onceligi"].map({
    "Kritik": 0,
    "Dusuk": 1,
    "Orta": 2,
    "Yuksek":3
})

df["Makine_Saglik_Durumu"] = df ["Makine_Saglik_Durumu"].map({
    "Kritik": 0,
    "Yıpranmış": 1,
    "Zayıf": 2,
    "İyi": 3,
    "Kusursuz":4
})

# %%
df
# Out:
#      Bakim_Onceligi  Makine_Saglik_Durumu  Makine_Yasi  Calisma_Saati  \
# 0                 1                   4.0          1.0         1960.0
# 1                 2                   4.0          7.0          924.0
# 2                 0                   1.0          5.0         2113.0
# 3                 0                   2.0         12.0         2898.0
# 4                 2                   0.0         10.0         1925.0
# ..              ...                   ...          ...            ...
# 495               1                   1.0          1.0         1354.0
# 496               2                   1.0          6.0         1868.0
# 497               3                   2.0         12.0         1797.0
# 498               1                   0.0          4.0          875.0
# 499               0                   2.0          8.0         1370.0
#
#      Titreşim_Seviyesi  Ariza_Sayisi  Duruş_Suresi_Saat  Ortam_Sicakligi  \
# 0                 1.16           3.0                3.0             41.8
# 1                 1.40           1.0                1.0             30.2
# 2                 1.69           4.0                4.0             25.7
# 3                 2.20           0.0                0.0             22.0
# 4                 1.26           3.0                3.0             28.1
# ..                 ...           ...                ...              ...
# 495               2.34           5.0                5.0             43.2
# 496               3.57           4.0                4.0             33.1
# 497               1.55           3.0                3.0             29.2
# 498               0.88           2.0                2.0             38.7
# 499               1.82           0.0                0.0             42.1
#
#      Toplam_Bakim_Maliyeti  Vardiya_Gunduz  Vardiya_Hafta Sonu  \
# 0                 15767.85               0                   0
# 1                 14756.24               0                   0
# 2                 24976.29               0                   0
# 3                 25770.41               0                   0
# 4                 15910.66               0                   1
# ..                     ...             ...                 ...
# 495               23918.19               1                   0
# 496               24398.57               0                   1
# 497               23983.28               0                   1
# 498               18017.30               0                   1
# 499               19508.40               1                   0
#
#      Tesis_Bolgesi_Dogu  Tesis_Bolgesi_Guney  Tesis_Bolgesi_Kuzey  \
# 0                     0                    1                    0
# 1                     1                    0                    0
# 2                     0                    0                    0
# 3                     0                    0                    0
# 4                     1                    0                    0
# ..                  ...                  ...                  ...
# 495                   0                    0                    1
# 496                   0                    0                    1
# 497                   0                    0                    1
# 498                   1                    0                    0
# 499                   0                    1                    0
#
#      Tesis_Bolgesi_Merkez
# 0                       0
# 1                       0
# 2                       0
# 3                       1
# 4                       0
# ..                    ...
# 495                     0
# 496                     0
# 497                     0
# 498                     0
# 499                     0
#
# [500 rows x 15 columns]

# %%
df = df.dropna()

# %%
X = df.drop("Toplam_Bakim_Maliyeti", axis = 1)
Y = df["Toplam_Bakim_Maliyeti"]

# %%
x_train, x_test, y_train, y_test = train_test_split(X, Y,
                                                    test_size=0.2,
                                                    random_state=42) #Verinin bölünme işlemini gerçekleştiriyorum
skaler = StandardScaler()
sutunlar = ["Bakim_Onceligi", "Makine_Saglik_Durumu", "Makine_Yasi", "Calisma_Saati",
           "Titreşim_Seviyesi", "Ariza_Sayisi", "Duruş_Suresi_Saat", "Ortam_Sicakligi"]

x_train[sutunlar] = skaler.fit_transform(x_train[sutunlar])
x_test[sutunlar] = skaler.transform(x_test[sutunlar])

# %%
model = LinearRegression()
model.fit(x_train, y_train)
# Out:
# LinearRegression()

# %%
y_pred = model.predict(x_test)

# %%
mse = mean_squared_error(y_pred, y_test)
r2 = r2_score(y_pred, y_test)
mse, r2
# Out:
# (23308350.180916492, 0.18293224041338407)
